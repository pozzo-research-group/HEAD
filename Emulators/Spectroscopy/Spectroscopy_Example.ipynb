# %%
from spectroscopy import obtain_spectra
import numpy as np
import matplotlib.pyplot as plt

# %%
step = 4
radius_mean = 6
radius_std = 4
wavelength = np.linspace(400,800,81)
array = obtain_spectra(step, radius_mean, radius_std, wavelength)

# %%
plt.plot(array[:,0], array[:,1])
