# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'itr_6.xlsx'
df_spectra = pd.read_excel(path)

# %%
df_spectra
# Out:
#      Wavelength     E1     E2     E3     E4     E5     E6     E7     E8  \
# 0           400  0.958  1.039  1.044  1.083  1.081  1.020  1.030  0.921
# 1           405  0.948  1.027  1.032  1.071  1.069  1.008  1.016  0.908
# 2           410  0.940  1.017  1.022  1.060  1.058  0.996  1.004  0.896
# 3           415  0.933  1.006  1.012  1.049  1.048  0.985  0.993  0.884
# 4           420  0.926  0.997  1.003  1.039  1.039  0.974  0.982  0.873
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 96          880  0.266  0.461  0.378  0.300  0.303  1.834  0.307  2.088
# 97          885  0.260  0.450  0.371  0.295  0.298  1.742  0.290  1.992
# 98          890  0.254  0.428  0.355  0.287  0.290  1.579  0.268  1.817
# 99          895  0.249  0.411  0.343  0.282  0.285  1.448  0.252  1.669
# 100         900  0.247  0.399  0.335  0.279  0.282  1.331  0.239  1.532
#
#         F1  ...     A7     A8     B1     B2     B3     B4     B5     B6  \
# ...

# %%
path = 'itr6.csv'
df_vol = pd.read_csv(path)

# %%
df_vol
# Out:
#     Unnamed: 0  CTAB-stock  water-stock  GC-stock  AG-stock  AA-stock  \
# 0            0       416.0        287.0     256.0      89.0     150.0
# 1            1       416.0        285.0     256.0     150.0      91.0
# 2            2       416.0        285.0     256.0     133.0     108.0
# 3            3       416.0        296.0     256.0      80.0     150.0
# 4            4       416.0        281.0     256.0      95.0     150.0
# 5            5       416.0        398.0     256.0      67.0      61.0
# 6            6       416.0        339.0     256.0      50.0     137.0
# 7            7       416.0        401.0     256.0      58.0      67.0
# 8            8       416.0        335.0     256.0     113.0      78.0
# 9            9       416.0        294.0     256.0     103.0     129.0
# 10          10       416.0        360.0     256.0     143.0      23.0
# 11          11       416.0        326.0     256.0      93.0     107.0
# ...

# %%
target = pd.read_excel('Target_Rod.xlsx')
xt = target['Wavelength'].values
yt = target['B8'].values
plt.plot(xt,yt)
plt.plot(df_spectra['Wavelength'],df_spectra['F5'], label='Sample')
plt.plot(xt,yt, label = 'Target')
plt.legend()

# %%
plt.plot(df_spectra['Wavelength'],df_spectra['A8'], label='Sample')
plt.plot(df_spectra['Wavelength'],df_spectra['A1'], label='Sample')
