# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '../Sample_Spectra/Itr_6.xlsx'
df_spectra = pd.read_excel(path)

# %%
array = np.array(df_spectra)

# %%
for i in range(1,array.shape[1]):
    fig, ax = plt.subplots()
    plt.plot(array[:,0], array[:,i])
# Out:
# <ipython-input-34-10a206a7f030>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# find out if orings fit ,
# make sure there are enough well plate covers
# make sure there are enough stock solutions
# syntheisze stock solutions in 96 deep well plates
# count how mnay plates we have - cover plates, screws, kapton, brass
